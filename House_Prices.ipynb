# %% [markdown]
# <h1>Table of Contents<span class="tocSkip"></span></h1>
# <div class="toc"><ul class="toc-item"><li><span><a href="#Загрузка-данных,-постановка-задачи" data-toc-modified-id="Загрузка-данных,-постановка-задачи-1"><span class="toc-item-num">1&nbsp;&nbsp;</span>Загрузка данных, постановка задачи</a></span><ul class="toc-item"><li><span><a href="#Импорт-библиотек-и-таблиц" data-toc-modified-id="Импорт-библиотек-и-таблиц-1.1"><span class="toc-item-num">1.1&nbsp;&nbsp;</span>Импорт библиотек и таблиц</a></span></li><li><span><a href="#Описание-проекта" data-toc-modified-id="Описание-проекта-1.2"><span class="toc-item-num">1.2&nbsp;&nbsp;</span>Описание проекта</a></span></li><li><span><a href="#Описание-полей-таблицы" data-toc-modified-id="Описание-полей-таблицы-1.3"><span class="toc-item-num">1.3&nbsp;&nbsp;</span>Описание полей таблицы</a></span></li></ul></li><li><span><a href="#Исследование-данных" data-toc-modified-id="Исследование-данных-2"><span class="toc-item-num">2&nbsp;&nbsp;</span>Исследование данных</a></span><ul class="toc-item"><li><span><a href="#Анализ-таблицы-train" data-toc-modified-id="Анализ-таблицы-train-2.1"><span class="toc-item-num">2.1&nbsp;&nbsp;</span>Анализ таблицы train</a></span></li><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-2.2"><span class="toc-item-num">2.2&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span><ul class="toc-item"><li><span><a href="#Столбец-MasVnrArea" data-toc-modified-id="Столбец-MasVnrArea-2.2.1"><span class="toc-item-num">2.2.1&nbsp;&nbsp;</span>Столбец MasVnrArea</a></span></li><li><span><a href="#Столбец-GarageYrBlt" data-toc-modified-id="Столбец-GarageYrBlt-2.2.2"><span class="toc-item-num">2.2.2&nbsp;&nbsp;</span>Столбец GarageYrBlt</a></span></li><li><span><a href="#Столбец-MasVnrType" data-toc-modified-id="Столбец-MasVnrType-2.2.3"><span class="toc-item-num">2.2.3&nbsp;&nbsp;</span>Столбец MasVnrType</a></span><ul class="toc-item"><li><span><a href="#Метод-автоматического-заполнения-данных" data-toc-modified-id="Метод-автоматического-заполнения-данных-2.2.3.1"><span class="toc-item-num">2.2.3.1&nbsp;&nbsp;</span>Метод автоматического заполнения данных</a></span></li></ul></li><li><span><a href="#Столбец-BsmtQual" data-toc-modified-id="Столбец-BsmtQual-2.2.4"><span class="toc-item-num">2.2.4&nbsp;&nbsp;</span>Столбец BsmtQual</a></span></li><li><span><a href="#Столбец-BsmtExposure" data-toc-modified-id="Столбец-BsmtExposure-2.2.5"><span class="toc-item-num">2.2.5&nbsp;&nbsp;</span>Столбец BsmtExposure</a></span></li><li><span><a href="#Столбец-BsmtFinType1" data-toc-modified-id="Столбец-BsmtFinType1-2.2.6"><span class="toc-item-num">2.2.6&nbsp;&nbsp;</span>Столбец BsmtFinType1</a></span></li><li><span><a href="#Столбец-FireplaceQu" data-toc-modified-id="Столбец-FireplaceQu-2.2.7"><span class="toc-item-num">2.2.7&nbsp;&nbsp;</span>Столбец FireplaceQu</a></span></li><li><span><a href="#Столбец-GarageType" data-toc-modified-id="Столбец-GarageType-2.2.8"><span class="toc-item-num">2.2.8&nbsp;&nbsp;</span>Столбец GarageType</a></span></li><li><span><a href="#Столбец-GarageFinish" data-toc-modified-id="Столбец-GarageFinish-2.2.9"><span class="toc-item-num">2.2.9&nbsp;&nbsp;</span>Столбец GarageFinish</a></span></li><li><span><a href="#Столбец-GarageQual" data-toc-modified-id="Столбец-GarageQual-2.2.10"><span class="toc-item-num">2.2.10&nbsp;&nbsp;</span>Столбец GarageQual</a></span></li></ul></li></ul></li><li><span><a href="#Машинное-обучение" data-toc-modified-id="Машинное-обучение-3"><span class="toc-item-num">3&nbsp;&nbsp;</span>Машинное обучение</a></span><ul class="toc-item"><li><span><a href="#Baseline-без-заполненных-фичей" data-toc-modified-id="Baseline-без-заполненных-фичей-3.1"><span class="toc-item-num">3.1&nbsp;&nbsp;</span>Baseline без заполненных фичей</a></span></li><li><span><a href="#Baseline" data-toc-modified-id="Baseline-3.2"><span class="toc-item-num">3.2&nbsp;&nbsp;</span>Baseline</a></span></li><li><span><a href="#Отбираем-топ-фичи" data-toc-modified-id="Отбираем-топ-фичи-3.3"><span class="toc-item-num">3.3&nbsp;&nbsp;</span>Отбираем топ фичи</a></span></li><li><span><a href="#Подберем-лучшие-параметры-через-Hyperopt" data-toc-modified-id="Подберем-лучшие-параметры-через-Hyperopt-3.4"><span class="toc-item-num">3.4&nbsp;&nbsp;</span>Подберем лучшие параметры через Hyperopt</a></span></li><li><span><a href="#Построим-модель-с-найденными-гиперпараметрами" data-toc-modified-id="Построим-модель-с-найденными-гиперпараметрами-3.5"><span class="toc-item-num">3.5&nbsp;&nbsp;</span>Построим модель с найденными гиперпараметрами</a></span></li><li><span><a href="#Сделаем-кроссвалидацию-на-всех-данных" data-toc-modified-id="Сделаем-кроссвалидацию-на-всех-данных-3.6"><span class="toc-item-num">3.6&nbsp;&nbsp;</span>Сделаем кроссвалидацию на всех данных</a></span></li></ul></li><li><span><a href="#Анализ-таблицы-test" data-toc-modified-id="Анализ-таблицы-test-4"><span class="toc-item-num">4&nbsp;&nbsp;</span>Анализ таблицы test</a></span><ul class="toc-item"><li><span><a href="#Обработка-пропущенных-значений" data-toc-modified-id="Обработка-пропущенных-значений-4.1"><span class="toc-item-num">4.1&nbsp;&nbsp;</span>Обработка пропущенных значений</a></span><ul class="toc-item"><li><span><a href="#Столбец-GarageFinish" data-toc-modified-id="Столбец-GarageFinish-4.1.1"><span class="toc-item-num">4.1.1&nbsp;&nbsp;</span>Столбец GarageFinish</a></span></li><li><span><a href="#Столбец-KitchenQual" data-toc-modified-id="Столбец-KitchenQual-4.1.2"><span class="toc-item-num">4.1.2&nbsp;&nbsp;</span>Столбец KitchenQual</a></span></li><li><span><a href="#Столбец-BsmtQual" data-toc-modified-id="Столбец-BsmtQual-4.1.3"><span class="toc-item-num">4.1.3&nbsp;&nbsp;</span>Столбец BsmtQual</a></span></li><li><span><a href="#Столбец-BsmtExposure" data-toc-modified-id="Столбец-BsmtExposure-4.1.4"><span class="toc-item-num">4.1.4&nbsp;&nbsp;</span>Столбец BsmtExposure</a></span></li><li><span><a href="#Столбец-MSZoning" data-toc-modified-id="Столбец-MSZoning-4.1.5"><span class="toc-item-num">4.1.5&nbsp;&nbsp;</span>Столбец MSZoning</a></span></li><li><span><a href="#Столбец-GarageType" data-toc-modified-id="Столбец-GarageType-4.1.6"><span class="toc-item-num">4.1.6&nbsp;&nbsp;</span>Столбец GarageType</a></span></li></ul></li></ul></li><li><span><a href="#Сделаем-предсказание" data-toc-modified-id="Сделаем-предсказание-5"><span class="toc-item-num">5&nbsp;&nbsp;</span>Сделаем предсказание</a></span><ul class="toc-item"><li><span><a href="#Обучим-нашу-модель" data-toc-modified-id="Обучим-нашу-модель-5.1"><span class="toc-item-num">5.1&nbsp;&nbsp;</span>Обучим нашу модель</a></span></li><li><span><a href="#Сделаем-предсказание" data-toc-modified-id="Сделаем-предсказание-5.2"><span class="toc-item-num">5.2&nbsp;&nbsp;</span>Сделаем предсказание</a></span></li></ul></li></ul></div>

# %% [markdown]
# # Загрузка данных, постановка задачи

# %% [markdown]
# ## Импорт библиотек и таблиц

# %% [markdown]
# Ссылка на соревнование Kaggle https://www.kaggle.com/competitions/house-prices-advanced-regression-techniques/data

# %% [markdown]
# Таблицы для скачивания https://drive.google.com/file/d/1uXkcNOYI7XbhOi0wEmZex_xLPLOHDgiT/view?usp=sharing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
train = pd.read_csv(r"C:\Users\lavru\juoyter_notebook\House_Prices\Table\train.csv")

# %% [markdown]
# ## Описание проекта

# %% [markdown]
# Необходимо предсказать окончательную цену каждого дома исходя из 79 независимых переменных

# %% [markdown]
# ## Описание полей таблицы

# %% [markdown]
# * SalePrice - цена продажи недвижимости в долларах. (**Переменная, которую предсказываем**)
# * MSSubClass : класс здания
# * MSZoning : Общая классификация зонирования
# * LotFrontage : Линейные футы улицы, соединенной с недвижимостью
# * LotArea : Размер участка в квадратных футах.
# * Street : Тип подъездной дороги
# * Alley : Тип доступа к аллее
# * LotShape : Общая форма объекта
# * LandContour : Плоскостность участка
# * Utilities : Тип доступных коммунальных услуг
# * LotConfig : конфигурация лота
# * LandSlope : Уклон участка
# * Neighborhood : Физические местоположения в черте города Эймс.
# * Condition1 : Близость к главной дороге или железной дороге
# * Condition2: близость к главной дороге или железной дороге (при наличии второй)
# * BldgType : Тип жилья
# * HouseStyle : стиль жилья
# * OverallQual : общее качество материала и отделки.
# * TotalCond : общая оценка состояния
# * YearBuilt : Первоначальная дата постройки
# * YearRemodAdd : Дата ремоделирования
# * RoofStyle : Тип крыши
# * RoofMatl : Материал крыши
# * Exterior1st : Наружное покрытие дома
# * Exterior2nd : Внешнее покрытие дома (если более одного материала)
# * MasVnrType : Тип каменной кладки
# * MasVnrArea : Площадь каменной кладки в квадратных футах.
# * ExterQual : качество материалов экстерьера
# * ExterCond : Текущее состояние материала снаружи.
# * Foundation : Тип фундамента
# * BsmtQual : Высота подвала
# * BsmtCond : Общее состояние подвала
# * BsmtExposure : Стены подвала на уровне сада или выхода.
# * BsmtFinType1 : Качество отделки цокольного этажа.
# * BsmtFinSF1 : тип 1 готовых квадратных футов
# * BsmtFinType2 : Качество второй готовой области (если присутствует)
# * BsmtFinSF2 : тип 2 готовых квадратных футов
# * BsmtUnfSF : Незавершенные квадратные футы подвального помещения.
# * TotalBsmtSF : Общая площадь подвала в квадратных футах.
# * Heating : Тип отопления
# * HeatingQC : Качество и состояние отопления
# * CentralAir : Центральное кондиционирование воздуха
# * Electrical : Электрическая система
# * 1stFlrSF : Квадратные футы первого этажа
# * 2ndFlrSF : Квадратные футы второго этажа.
# * LowQualFinSF : квадратные футы с отделкой низкого качества (все этажи)
# * GrLivArea : жилая площадь над землей в квадратных футах
# * BsmtFullBath : Ванные комнаты в подвале
# * BsmtHalfBath : Половина ванных комнат в подвале
# * FullBath : полностью оборудованные ванные комнаты выше уровня земли.
# * HalfBath : полуванны выше уровня земли.
# * Bedroom : Количество спален над цокольным этажом
# * Kitchen : Количество кухонь
# * KitchenQual : Качество кухни
# * TotRmsAbvGrd : Общее количество комнат выше класса (не включая ванные комнаты)
# * Functional : Рейтинг домашней функциональности
# * Fireplaces : Количество каминов
# * FireplaceQu : Качество камина
# * GarageType : место в гараже
# * GarageYrBlt : Год постройки гаража.
# * GarageFinish : Внутренняя отделка гаража
# * GarageCars : Размер гаража по вместимости автомобиля
# * GarageArea : Размер гаража в квадратных футах.
# * GarageQual : качество гаража
# * GarageCond : Гаражное состояние
# * PavedDrive : Асфальтированная дорога
# * WoodDeckSF : площадь деревянной палубы в квадратных футах.
# * OpenPorchSF : площадь открытого крыльца в квадратных футах.
# * EnclosedPorch : закрытая площадь крыльца в квадратных футах.
# * 3SsnPorch : площадь крыльца для трех сезонов в квадратных футах.
# * ScreenPorch : Площадь крыльца экрана в квадратных футах.
# * PoolArea : площадь бассейна в квадратных футах.
# * PoolQC : качество бассейна
# * Fence : Качество забора
# * MiscFeature : Разная функция, не включенная в другие категории.
# * MiscVal : Значение различных функций
# * MoSold : Месяц продажи
# * YrSold : Год продажи
# * SaleType : Тип продажи
# * SaleCondition : Состояние продажис

# %% [markdown]
# # Исследование данных

# %% [markdown]
# ## Анализ таблицы train

# %%
pd.options.display.max_columns = 100

# %%
pd.options.display.max_rows = 300

# %%
train
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
(train.isna().mean()*100).sort_values()
# Out:
# Id                0.000000
# TotalBsmtSF       0.000000
# Heating           0.000000
# SaleCondition     0.000000
# CentralAir        0.000000
# 1stFlrSF          0.000000
# 2ndFlrSF          0.000000
# LowQualFinSF      0.000000
# GrLivArea         0.000000
# BsmtFullBath      0.000000
# BsmtHalfBath      0.000000
# FullBath          0.000000
# HalfBath          0.000000
# BedroomAbvGr      0.000000
# KitchenAbvGr      0.000000
# KitchenQual       0.000000
# TotRmsAbvGrd      0.000000
# Functional        0.000000
# SaleType          0.000000
# YrSold            0.000000
# MoSold            0.000000
# MiscVal           0.000000
# PoolArea          0.000000
# ScreenPorch       0.000000
# BsmtUnfSF         0.000000
# 3SsnPorch         0.000000
# OpenPorchSF       0.000000
# WoodDeckSF        0.000000
# PavedDrive        0.000000
# GarageArea        0.000000
# GarageCars        0.000000
# Fireplaces        0.000000
# EnclosedPorch     0.000000
# BsmtFinSF2        0.000000
# ...

# %% [markdown]
# В столбцах пропусков меньше 5-6%: MasVnrType (тип каменной вкладки), MasVnrArea (Площадь каменной кладки в квадратных футах), BsmtQual (Высота подвала), BsmtCond (Общее состояние подвала), BsmtExposure (Стены подвала на уровне сада или выхода), BsmtFinType1 (Качество отделки цокольного этажа), BsmtFinType2 (Качество второй готовой области), Electrical (Электрическая система), GarageType (место в гараже), GarageYrBlt (Год постройки гаража), GarageFinish (Внутренняя отделка гаража), GarageQual (качество гаража), GarageCond (Гаражное состояние) <br>
#
# Столбцы PoolQC (качество бассейна), MiscFeature (другие функции дома), Alley (тип доступа к аллеи), Fence (качество забора) предлагаю не брать для машинного обучения.
# 1. Очень много пропущенных данных
# 2. Эти переменные не являются такими критичными, как например площадь участка, кол-во этажей и т.д., тем самым они в меньшей степени повлияют на обучение
#
# Столбцы FireplaceQu, LotFrontage мы дальнейшем проанализируем и поймем стоит ли их заполнять или лучше удалить

# %% [markdown]
# Удалим ненужные столбцы

# %%
train = train.drop(["PoolQC", "MiscFeature", "Alley", "Fence"], axis=1)

# %%
train.dtypes
# Out:
# Id                 int64
# MSSubClass         int64
# MSZoning          object
# LotFrontage      float64
# LotArea            int64
# Street            object
# LotShape          object
# LandContour       object
# Utilities         object
# LotConfig         object
# LandSlope         object
# Neighborhood      object
# Condition1        object
# Condition2        object
# BldgType          object
# HouseStyle        object
# OverallQual        int64
# OverallCond        int64
# YearBuilt          int64
# YearRemodAdd       int64
# RoofStyle         object
# RoofMatl          object
# Exterior1st       object
# Exterior2nd       object
# MasVnrType        object
# MasVnrArea       float64
# ExterQual         object
# ExterCond         object
# Foundation        object
# BsmtQual          object
# BsmtCond          object
# BsmtExposure      object
# BsmtFinType1      object
# BsmtFinSF1         int64
# BsmtFinType2      object
# BsmtFinSF2         int64
# BsmtUnfSF          int64
# ...

# %% [markdown]
# ## Обработка пропущенных значений

# %% [markdown]
# Посмотрим на корреляцию данных через phik, чтобы понять какие параметры больше всего влияют на нашу искомую переменную SalePrice

# %%
! pip install phik

# %%
import phik
from phik.report import plot_correlation_matrix
from phik import report

# %%
phik_overview = train.phik_matrix()
# Out:
# interval columns not set, guessing: ['Id', 'MSSubClass', 'LotFrontage', 'LotArea', 'OverallQual', 'OverallCond', 'YearBuilt', 'YearRemodAdd', 'MasVnrArea', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF', 'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea', 'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr', 'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageYrBlt', 'GarageCars', 'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch', 'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice']

# %%
phik_overview['SalePrice'].sort_values(ascending=False)
# Out:
# SalePrice        1.000000
# GrLivArea        0.887026
# 2ndFlrSF         0.854449
# OverallQual      0.820348
# MasVnrArea       0.770451
# GarageCars       0.759608
# GarageArea       0.700441
# Neighborhood     0.687262
# ExterQual        0.675927
# KitchenQual      0.661979
# BsmtQual         0.655620
# TotRmsAbvGrd     0.636482
# YearBuilt        0.621852
# FullBath         0.613686
# TotalBsmtSF      0.576548
# GarageFinish     0.570523
# CentralAir       0.538376
# GarageYrBlt      0.532719
# HeatingQC        0.514728
# BsmtFinSF1       0.511026
# 1stFlrSF         0.510018
# YearRemodAdd     0.492112
# BsmtUnfSF        0.470490
# Fireplaces       0.456013
# Foundation       0.452841
# FireplaceQu      0.452303
# MSZoning         0.451654
# PoolArea         0.434787
# WoodDeckSF       0.433796
# Exterior2nd      0.413211
# Exterior1st      0.408264
# GarageType       0.406528
# GarageQual       0.396982
# MasVnrType       0.395657
# BsmtFinType1     0.375055
# ...

# %% [markdown]
# Слабо коррелируют BsmtCond (0.2), BsmtFinType2(0.09), GarageCond(0.24), LotFrontage(0.33), Electrical(0.3) из тех столбцов, в которых пропущенные значения. Удалим их

# %%
train = train.drop(["BsmtCond", "BsmtFinType2", "GarageCond", "LotFrontage", "Electrical"], axis=1)

# %%
table = pd.DataFrame((train.isna().mean()*100) != 0)

# %%
missing_val = table[table[0] == True].index

# %%
train[missing_val].dtypes
# Out:
# MasVnrType       object
# MasVnrArea      float64
# BsmtQual         object
# BsmtExposure     object
# BsmtFinType1     object
# FireplaceQu      object
# GarageType       object
# GarageYrBlt     float64
# GarageFinish     object
# GarageQual       object
# dtype: object

# %% [markdown]
# Заполним сначала числовые значения сталбцов MasVnrArea, GarageYrBlt. Потом заполним категориальные фичи

# %% [markdown]
# ### Столбец MasVnrArea

# %%
train["MasVnrArea"].isna().mean()*100
# Out:
# 0.547945205479452

# %% [markdown]
# 0,54 % пропущенных данных - достаточно мало

# %%
phik_overview['MasVnrArea'].sort_values(ascending=False).head(5)
# Out:
# MasVnrArea    1.000000
# SalePrice     0.770451
# GrLivArea     0.764884
# 2ndFlrSF      0.734320
# MasVnrType    0.599650
# Name: MasVnrArea, dtype: float64

# %% [markdown]
# Разабьем столбец SalePrice_group на 5 равных по количеству данных групп

# %%
train["SalePrice_group"] = pd.qcut(train['SalePrice'], q=5)

# %% [markdown]
# Разабьем столбец GrLivArea на 4 равных по количеству данных групп

# %%
train['GrLivArea_group'] = pd.qcut(train['GrLivArea'], q=4)

# %%
train.groupby(["GrLivArea_group","SalePrice_group"])["MasVnrArea"].agg(["count","mean","median"])
# Out:
#                                          count        mean  median
# GrLivArea_group   SalePrice_group
# (333.999, 1129.5] (34899.999, 124000.0]    186   25.602151     0.0
#                   (124000.0, 147000.0]     135   38.525926     0.0
#                   (147000.0, 179280.0]      43   96.232558     0.0
#                   (179280.0, 230000.0]       1    0.000000     0.0
#                   (230000.0, 755000.0]       0         NaN     NaN
# (1129.5, 1464.0]  (34899.999, 124000.0]     78   46.974359     0.0
#                   (124000.0, 147000.0]      77   47.714286     0.0
#                   (147000.0, 179280.0]     126  100.230159     0.0
#                   (179280.0, 230000.0]      75   83.133333    24.0
#                   (230000.0, 755000.0]       7   37.142857     0.0
# (1464.0, 1776.75] (34899.999, 124000.0]     21   12.095238     0.0
#                   (124000.0, 147000.0]      54   47.814815     0.0
# ...

# %%
table = pd.DataFrame(train.groupby(["GrLivArea_group","SalePrice_group"])["MasVnrArea"].agg(["count","mean"]))

# %% [markdown]
# Больше мы не можем разбивать на группы, т.к. уже данных становится все меньше в каждой группе. Заполнять будем средним значением т.к. в данных огромное кол-во нулей, тем самым медианное значение будет равно нулю

# %%
train = train.merge(table, how = 'left', on=["SalePrice_group","GrLivArea_group"])

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %%
train.loc[train["MasVnrArea"].isna(), "MasVnrArea"] = train[train["MasVnrArea"].isna()]["MasVnrArea"].fillna(train["mean"])

# %% [markdown]
# Удалим ненужные столбцы

# %%
train = train.drop(["SalePrice_group", "GrLivArea_group", "count", "mean"], axis=1)

# %%
train["MasVnrArea"].isna().mean()*100
# Out:
# 0.0

# %% [markdown]
# ### Столбец GarageYrBlt

# %%
train["GarageYrBlt"].isna().mean()*100
# Out:
# 5.5479452054794525

# %%
phik_overview['GarageYrBlt'].sort_values(ascending=False).head(5)
# Out:
# GarageYrBlt     1.000000
# YearBuilt       0.942558
# YearRemodAdd    0.866337
# Neighborhood    0.791726
# Foundation      0.676139
# Name: GarageYrBlt, dtype: float64

# %% [markdown]
# Разабьем столбец YearBuilt на группы по 20 лет, начиная с 1952 году разабьем по десятилетиям т.к. информации стало гораздо больше

# %%
cut_bins = [1871,1892,1912,1932,1952,1962, 1972, 1982, 1992, 2002,2004,2006,2007, 2010]

# %%
 train["YearBuilt_group"] = pd.cut(train['YearBuilt'],bins=cut_bins)

# %%
table = train.groupby("YearBuilt_group")["GarageYrBlt"].agg(["count","mean","median"])

# %%
table
# Out:
#                  count         mean  median
# YearBuilt_group
# (1871, 1892]        11  1964.272727  1963.0
# (1892, 1912]        28  1953.464286  1958.0
# (1912, 1932]       130  1944.607692  1930.5
# (1932, 1952]       130  1953.953846  1949.0
# (1952, 1962]       178  1961.471910  1959.0
# (1962, 1972]       183  1970.103825  1968.0
# (1972, 1982]       136  1977.698529  1977.0
# (1982, 1992]        66  1988.227273  1988.0
# (1992, 2002]       199  1997.974874  1998.0
# (2002, 2004]        98  2003.571429  2004.0
# (2004, 2006]       130  2005.592308  2006.0
# (2006, 2007]        48  2007.187500  2007.0
# (2007, 2010]        42  2008.642857  2009.0

# %%
fig = plt.figure(figsize=(15,5))

table1 = train.groupby(['YearBuilt_group'], as_index=False)['GarageYrBlt'].mean().sort_values(by='GarageYrBlt')

ax = sns.boxplot(data=train, x="YearBuilt_group", y="GarageYrBlt", order=table1['YearBuilt_group'].to_list(), palette="Set1")
ax.set_xticklabels(ax.get_xticklabels(), rotation=45)
fig.suptitle("Mean GarageYrBlt",fontsize=25)
# Out:
# Text(0.5, 0.98, 'Mean GarageYrBlt')

# %% [markdown]
# На некоторых отрезках присутствуют выбросы, воспользуемся медианным значением для замены данных

# %%
train = train.merge(table, how = 'left', on=["YearBuilt_group"])

# %%
train.head(5)
# Out:
#    Id  MSSubClass MSZoning  LotArea Street LotShape LandContour Utilities  \
# 0   1          60       RL     8450   Pave      Reg         Lvl    AllPub
# 1   2          20       RL     9600   Pave      Reg         Lvl    AllPub
# 2   3          60       RL    11250   Pave      IR1         Lvl    AllPub
# 3   4          70       RL     9550   Pave      IR1         Lvl    AllPub
# 4   5          60       RL    14260   Pave      IR1         Lvl    AllPub
#
#   LotConfig LandSlope Neighborhood Condition1 Condition2 BldgType HouseStyle  \
# 0    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 1       FR2       Gtl      Veenker      Feedr       Norm     1Fam     1Story
# 2    Inside       Gtl      CollgCr       Norm       Norm     1Fam     2Story
# 3    Corner       Gtl      Crawfor       Norm       Norm     1Fam     2Story
# 4       FR2       Gtl      NoRidge       Norm       Norm     1Fam     2Story
#
# ...

# %%
train.loc[train["GarageYrBlt"].isna(), "GarageYrBlt"] = train["GarageYrBlt"].fillna(train["median"])

# %% [markdown]
# Проверим заполненность пропусков

# %%
train[train["GarageYrBlt"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, YearBuilt_group, count, mean, median]
# Index: []

# %% [markdown]
# Все пропуски заполнены

# %% [markdown]
# Удалим ненужные столбцы

# %%
train = train.drop(["YearBuilt_group", "count", "mean", "median"], axis=1)

# %%
len(train)
# Out:
# 1460

# %% [markdown]
# ### Столбец MasVnrType

# %%
train["MasVnrType"].isna().mean()*100
# Out:
# 0.547945205479452

# %%
phik_overview['MasVnrType'].sort_values(ascending=False).head(5)
# Out:
# MasVnrType      1.000000
# Neighborhood    0.628516
# MasVnrArea      0.599650
# BsmtQual        0.568488
# ExterQual       0.564437
# Name: MasVnrType, dtype: float64

# %% [markdown]
# Переменная имеет корреляцию с столбцами Neighborhood, MasVnrArea,BsmtQual, ExterQual

# %%
pd.pivot_table(train,index=["Neighborhood","MasVnrType"],values=["1stFlrSF"],aggfunc='count')
# Out:
#                          1stFlrSF
# Neighborhood MasVnrType
# Blmngtn      BrkFace           16
#              None               1
# Blueste      None               2
# BrDale       BrkFace           15
#              None               1
# BrkSide      BrkCmn             1
#              BrkFace            2
#              None              55
# ClearCr      BrkCmn             2
#              BrkFace            5
#              None              20
#              Stone              1
# CollgCr      BrkFace           61
#              None              74
#              Stone             14
# Crawfor      BrkFace           11
#              None              36
#              Stone              3
# Edwards      BrkFace           15
#              None              75
#              Stone             10
# Gilbert      BrkFace           18
#              None              58
#              Stone              2
# IDOTRR       BrkFace            1
#              None              36
# ...

# %% [markdown]
# Достаточно большое кол-во районов и наличие неоднозначности в данных, что делает заполнение отсутствующих значений MasVnrType сложным, поэтому воспользуемся машинным обучение, чтобы предсказать эти значения

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, f1_score, recall_score, confusion_matrix,precision_score

# %%
# !pip install catboost

# %%
import catboost as ctb

# %% [markdown]
# Удалим столбцы с пропущенными данными и с пропусками в столбце MasVnrType

# %%
table = pd.DataFrame((train.isna().mean()*100) != 0)
missing_val = table[table[0] == True].index
train[missing_val].dtypes
# Out:
# MasVnrType      object
# BsmtQual        object
# BsmtExposure    object
# BsmtFinType1    object
# FireplaceQu     object
# GarageType      object
# GarageFinish    object
# GarageQual      object
# dtype: object

# %%
train_drop = train.drop(missing_val[1:], axis=1)

# %%
train_drop = train_drop[train_drop["MasVnrType"].notna()]

# %% [markdown]
# Посмотрим на процентное соотношения классов MasVnrType ко всему train

# %%
train_drop["MasVnrType"].value_counts()*100 / train.shape[0]
# Out:
# None       59.178082
# BrkFace    30.479452
# Stone       8.767123
# BrkCmn      1.027397
# Name: MasVnrType, dtype: float64

# %% [markdown]
# Классы несбалансированные

# %% [markdown]
# Закадируем переменные по столбцу MasVnrType

# %%
le = LabelEncoder()
train_drop['label'] = le.fit_transform(train_drop.MasVnrType.values)

# %% [markdown]
# Создадим обучающую и тестовую выборку

# %%
X,Y=train_drop.drop(['MasVnrType','label'],axis=1),train_drop['label']
X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                    test_size=0.2,
                                                    random_state=42,
                                                    shuffle=True)

# %% [markdown]
# Сохраним категориальные фичи

# %%
categorical_features_indices = np.where(X_train.dtypes == np.object_)[0]

# %%
model=ctb.CatBoostClassifier(loss_function='MultiClass',
                            random_seed=42,
                            verbose=100
                            )
model.fit(X_train,y_train,cat_features=categorical_features_indices, eval_set=None, plot=True)
# Out:
# MetricVisualizer(layout=Layout(align_self='stretch', height='500px'))
# Learning rate set to 0.079731
# 0:	learn: 1.2061573	total: 86.1ms	remaining: 1m 25s
# 100:	learn: 0.1552453	total: 12.3s	remaining: 1m 49s
# 200:	learn: 0.0996866	total: 25.4s	remaining: 1m 41s
# 300:	learn: 0.0730106	total: 40.7s	remaining: 1m 34s
# 400:	learn: 0.0562184	total: 57s	remaining: 1m 25s
# 500:	learn: 0.0448739	total: 1m 11s	remaining: 1m 11s
# 600:	learn: 0.0361060	total: 1m 27s	remaining: 57.9s
# 700:	learn: 0.0299644	total: 1m 43s	remaining: 44.2s
# 800:	learn: 0.0252780	total: 1m 59s	remaining: 29.8s
# 900:	learn: 0.0219079	total: 2m 15s	remaining: 14.9s
# 999:	learn: 0.0192458	total: 2m 30s	remaining: 0us

# %%
train_pred = model.predict(X_train)
train_acc = accuracy_score(y_train,train_pred)
print('Train Accuracy: ', train_acc)
 
test_pred = model.predict(X_test)
test_acc = accuracy_score(y_test,test_pred)
print('Test Accuracy:', test_acc)
y_pred=test_pred
confusion = confusion_matrix(y_test, test_pred)
print('Confusion Matrix\n')
print(confusion)
# Out:
# Train Accuracy:  0.9896640826873385
# Test Accuracy: 0.9347079037800687
# Confusion Matrix
#
# [[  0   2   0   0]
#  [  0  88   0   6]
#  [  0   2 171   0]
#  [  0   8   1  13]]

# %%
from sklearn.metrics import classification_report

# %%
labels = train_drop[["MasVnrType","label"]].value_counts().reset_index().sort_values(by="label")["MasVnrType"].to_list()

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
print(classification_report(y_test, test_pred, target_names=labels))
# Out:
#               precision    recall  f1-score   support
#
#       BrkCmn       0.00      0.00      0.00         2
#      BrkFace       0.88      0.94      0.91        94
#         None       0.99      0.99      0.99       173
#        Stone       0.68      0.59      0.63        22
#
#     accuracy                           0.93       291
#    macro avg       0.64      0.63      0.63       291
# weighted avg       0.93      0.93      0.93       291

# %% [markdown]
# Как мы видим по метрике F1 мы хорошо предсказываем переменные BrkFace и None, по остальным данным значение F1 маленькое из-за дисбаланса классов

# %% [markdown]
# Предскажем модель на неизвестных данных столбца MasVnrType

# %%
pred = train[train["MasVnrType"].isna()].drop(missing_val[1:], axis=1)

# %%
pred = pred.drop(['MasVnrType'],axis=1)

# %%
mod = model.predict_proba(pred)

# %%
type_MasVnr = []
name = []
for i in range(len(mod)):
    max_val = np.max(mod[i])
    val = np.where(mod[i] == max_val)
    if val[0] == 0:
        type_MasVnr.append("BrkCmn")
    elif val[0] == 1:
        type_MasVnr.append("BrkFace")
    elif val[0] == 2:
        type_MasVnr.append("None")
    elif val[0] == 3:
        type_MasVnr.append("Stone")

# %% [markdown]
# Получили неизвестные значения MasVnrType для каждой строчки

# %%
type_MasVnr
# Out:
# ['BrkFace',
#  'BrkFace',
#  'Stone',
#  'BrkFace',
#  'Stone',
#  'Stone',
#  'Stone',
#  'BrkFace']

# %%
Id = train[train["MasVnrType"].isna()]["Id"].to_list()

# %% [markdown]
# Создадим таблицу для merge

# %%
table1 = pd.DataFrame({"MasVnrType_ML":type_MasVnr,
                      "id_ML":Id})

# %%
table1
# Out:
#   MasVnrType_ML  id_ML
# 0       BrkFace    235
# 1       BrkFace    530
# 2         Stone    651
# 3       BrkFace    937
# 4         Stone    974
# 5         Stone    978
# 6         Stone   1244
# 7       BrkFace   1279

# %%
train = train.merge(table1 , how = "left", left_on = "Id", right_on = "id_ML")

# %% [markdown]
# Если в одном из столбце (MasVnrType и MasVnrType_ML) будет какое-либо значение, то это значение будет записано в поле MasVnrType

# %%
train['MasVnrType'] = train['MasVnrType'].combine_first(train['MasVnrType_ML'])

# %% [markdown]
# Проверим, есть ли пустые значения в MasVnrType

# %%
train[train["MasVnrType"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice, MasVnrType_ML, id_ML]
# Index: []

# %% [markdown]
# Все значения заполнены. Удалим ненужные столбцы

# %%
train = train.drop(["MasVnrType_ML", "id_ML"], axis=1)

# %% [markdown]
# #### Метод автоматического заполнения данных

# %% [markdown]
# Напишем функцию для автозаполнения отсутствующих данных методом ML. (Будем всегда считать, что классы несбалансированные)

# %%
def fil_pass_ML(data, field):
    table_miss_val = pd.DataFrame((data.isna().mean()*100) != 0)
    missing_val = table_miss_val[table_miss_val[0] == True].index
    
    table_object = ((data[missing_val].dtypes == np.object_)*1).reset_index()

    miss_field = table_object[table_object[0]==1]["index"].to_list() #отфильтрованные значения по типу данных - object
    miss_field.remove(field)
    
    data_drop = data.drop(miss_field, axis=1)
    data_drop = data_drop[data_drop[field].notna()]

    le = LabelEncoder()
    data_drop['label'] = le.fit_transform(data_drop[field].values)

    X,Y=data_drop.drop([field,'label'],axis=1),data_drop['label']
    X_train, X_test, y_train, y_test = train_test_split(X, Y,
                                                        test_size=0.2,
                                                        random_state=42,
                                                        shuffle=True)

    categorical_features_indices = np.where(X_train.dtypes == np.object_)[0]

    model=ctb.CatBoostClassifier(loss_function='MultiClass',
                                random_seed=42,
                                verbose=100,
                                auto_class_weights = "Balanced"
                                )
    model.fit(X_train,y_train,cat_features=categorical_features_indices, eval_set=None, plot=False)

    "предсказываем на тесте"
    train_pred = model.predict(X_train)
    test_pred = model.predict(X_test)

    labels = data_drop[[field,"label"]].value_counts().reset_index().sort_values(by="label")[field].to_list()
    try:
        print()
        print("___Отчет по основным метрикам для каждого класса___")
        print()
        print(classification_report(y_test, test_pred, target_names=labels))
    except Exception:
        print("Слишком много классов для отчета")

    pred = data[data[field].isna()].drop(miss_field, axis=1)
    pred = pred.drop([field],axis=1)

    mod = model.predict_proba(pred) #предсказываем для отсутствующих данных

    table_label = data_drop[[field, "label"]].value_counts().reset_index().sort_values(by="label")
    labels = table_label[field].to_list() #сохраняем labels  в порядке очереди

    "Соотносим названия предсказанных классов"
    type_MasVnr = []
    name = []
    for i in range(len(mod)):
        max_val = np.max(mod[i])
        val = np.where(mod[i] == max_val)
        if val[0] == 0:
            type_MasVnr.append(labels[0])
        elif val[0] == 1:
            type_MasVnr.append(labels[1])
        elif val[0] == 2:
            type_MasVnr.append(labels[2])
        elif val[0] == 3:
            type_MasVnr.append(labels[3])
        elif val[0] == 4:
            type_MasVnr.append(labels[4])
        elif val[0] == 5:
            type_MasVnr.append(labels[5])
        elif val[0] == 6:
            type_MasVnr.append(labels[6])
        elif val[0] == 7:
            type_MasVnr.append(labels[7])
        elif val[0] == 8:
            type_MasVnr.append(labels[8])
        elif val[0] == 9:
            type_MasVnr.append(labels[9])
        elif val[0] == 10:
            type_MasVnr.append(labels[10])
        elif val[0] == 11:
            type_MasVnr.append(labels[11])
        elif val[0] == 12:
            type_MasVnr.append(labels[12])
        elif val[0] == 13:
            type_MasVnr.append(labels[13])
        elif val[0] == 14:
            type_MasVnr.append(labels[14])
        elif val[0] == 15:
            type_MasVnr.append(labels[15])
        elif val[0] == 16:
            type_MasVnr.append(labels[16])

    Id = data[data[field].isna()]["Id"].to_list()

    table_merge = pd.DataFrame({"label_ML":type_MasVnr,
                          "id_ML":Id})


    data = data.merge(table_merge , how = "left", left_on = "Id", right_on = "id_ML")
    data[field] = data[field].combine_first(data['label_ML'])

    data = data.drop(["label_ML", "id_ML"], axis=1)

    return data

# %% [markdown]
# ### Столбец BsmtQual

# %%
train["BsmtQual"].isna().mean()*100
# Out:
# 2.5342465753424657

# %%
phik_overview['BsmtQual'].sort_values(ascending=False).head(5)
# Out:
# BsmtQual        1.000000
# ExterQual       0.817733
# KitchenQual     0.781264
# Neighborhood    0.778347
# YearBuilt       0.713968
# Name: BsmtQual, dtype: float64

# %%
train.groupby(["ExterQual","KitchenQual","BsmtQual"])["BsmtQual"].agg(["count"])
# Out:
#                                 count
# ExterQual KitchenQual BsmtQual
# Ex        Ex          Ex           39
#                       Gd            2
#                       TA            1
#           Gd          Ex            5
#                       TA            3
#           TA          Gd            2
# Fa        Fa          Fa            1
#                       TA            5
#           TA          Fa            1
#                       Gd            1
#                       TA            4
# Gd        Ex          Ex           22
#                       Gd           21
#                       TA            4
#           Gd          Ex           44
#                       Gd          341
#                       TA           22
#           TA          Ex            1
#                       Fa            1
#                       Gd           15
#                       TA           16
# TA        Ex          Fa            2
#                       Gd            2
# ...

# %% [markdown]
# Достаточно большой разброс данных, для некоторых категорий данных слишком мало, поэтому мы не можем сделать однозначные выводы

# %% [markdown]
# Посмотрим на процентное соотношения классов BsmtQual ко всему train

# %%
train["BsmtQual"].value_counts()*100 / train.shape[0]
# Out:
# TA    44.452055
# Gd    42.328767
# Ex     8.287671
# Fa     2.397260
# Name: BsmtQual, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные в столбцу BsmtQual

# %% [markdown]
# Заполним данные с помощью ML

# %%
train = fil_pass_ML(train,"BsmtQual")
# Out:
# Learning rate set to 0.07965
# 0:	learn: 1.3353618	total: 162ms	remaining: 2m 41s
# 100:	learn: 0.4004387	total: 15.4s	remaining: 2m 17s
# 200:	learn: 0.2265803	total: 29.4s	remaining: 1m 56s
# 300:	learn: 0.1805630	total: 44.2s	remaining: 1m 42s
# 400:	learn: 0.1519365	total: 59.8s	remaining: 1m 29s
# 500:	learn: 0.1325926	total: 1m 14s	remaining: 1m 14s
# 600:	learn: 0.1162410	total: 1m 29s	remaining: 59.7s
# 700:	learn: 0.1028162	total: 1m 44s	remaining: 44.7s
# 800:	learn: 0.0915153	total: 1m 57s	remaining: 29.3s
# 900:	learn: 0.0826809	total: 2m 11s	remaining: 14.5s
# 999:	learn: 0.0748266	total: 2m 26s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Ex       0.91      0.64      0.75        33
#           Fa       0.80      0.44      0.57         9
#           Gd       0.83      0.88      0.85       114
#           TA       0.88      0.93      0.90       129
#
# ...

# %%
train[train["BsmtQual"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец BsmtExposure

# %%
train["BsmtExposure"].isna().mean()*100
# Out:
# 2.6027397260273974

# %% [markdown]
# Посмотрим на процентное соотношения классов BsmtExposure ко всему train

# %%
train["BsmtExposure"].value_counts()*100 / train.shape[0]
# Out:
# No    65.273973
# Av    15.136986
# Gd     9.178082
# Mn     7.808219
# Name: BsmtExposure, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца BsmtExposure

# %% [markdown]
# Заполним значение методом машинного обучения

# %%
train = fil_pass_ML(train,"BsmtExposure")
# Out:
# Learning rate set to 0.079647
# 0:	learn: 1.3733085	total: 45.4ms	remaining: 45.3s
# 100:	learn: 0.8323873	total: 15.2s	remaining: 2m 15s
# 200:	learn: 0.5345077	total: 29.8s	remaining: 1m 58s
# 300:	learn: 0.3884284	total: 42.5s	remaining: 1m 38s
# 400:	learn: 0.2964397	total: 55.3s	remaining: 1m 22s
# 500:	learn: 0.2377748	total: 1m 7s	remaining: 1m 7s
# 600:	learn: 0.1932703	total: 1m 19s	remaining: 53s
# 700:	learn: 0.1652847	total: 1m 34s	remaining: 40.3s
# 800:	learn: 0.1425472	total: 1m 49s	remaining: 27.2s
# 900:	learn: 0.1245212	total: 2m 5s	remaining: 13.7s
# 999:	learn: 0.1107075	total: 2m 20s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Av       0.38      0.40      0.39        48
#           Gd       0.38      0.42      0.40        24
#           Mn       0.00      0.00      0.00        20
#           No       0.84      0.88      0.86       193
#
# ...

# %%
train[train["BsmtExposure"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец BsmtFinType1

# %%
train["BsmtFinType1"].isna().mean()*100
# Out:
# 2.5342465753424657

# %%
train["BsmtFinType1"].value_counts()
# Out:
# Unf    430
# GLQ    418
# ALQ    220
# BLQ    148
# Rec    133
# LwQ     74
# Name: BsmtFinType1, dtype: int64

# %% [markdown]
# Как мы видим столбец BsmtFinType1 имеет 6 категорий

# %% [markdown]
# Заполним пропущенные значения методом машинного обучения

# %% [markdown]
# Посмотрим на процентное соотношения классов BsmtFinType1 ко всему train

# %%
train["BsmtFinType1"].value_counts()*100 / train.shape[0]
# Out:
# Unf    29.452055
# GLQ    28.630137
# ALQ    15.068493
# BLQ    10.136986
# Rec     9.109589
# LwQ     5.068493
# Name: BsmtFinType1, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца BsmtFinType1

# %%
train = fil_pass_ML(train,"BsmtFinType1")
# Out:
# Learning rate set to 0.07965
# 0:	learn: 1.7174885	total: 57.9ms	remaining: 57.9s
# 100:	learn: 0.8104537	total: 31.2s	remaining: 4m 38s
# 200:	learn: 0.5158221	total: 1m 2s	remaining: 4m 8s
# 300:	learn: 0.3907790	total: 1m 36s	remaining: 3m 43s
# 400:	learn: 0.2999163	total: 2m 9s	remaining: 3m 13s
# 500:	learn: 0.2446041	total: 2m 42s	remaining: 2m 42s
# 600:	learn: 0.2016843	total: 3m 16s	remaining: 2m 10s
# 700:	learn: 0.1701121	total: 3m 50s	remaining: 1m 38s
# 800:	learn: 0.1478037	total: 4m 17s	remaining: 1m 4s
# 900:	learn: 0.1281801	total: 4m 45s	remaining: 31.4s
# 999:	learn: 0.1114687	total: 5m 12s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#          ALQ       0.44      0.53      0.48        38
#          BLQ       0.43      0.10      0.16        30
#          GLQ       0.84      0.82      0.83        80
#          LwQ       0.47      0.42      0.44        19
# ...

# %%
train[train["BsmtFinType1"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец FireplaceQu

# %%
train["FireplaceQu"].isna().mean()*100
# Out:
# 47.26027397260274

# %%
train["FireplaceQu"].value_counts(dropna=True)
# Out:
# Gd    380
# TA    313
# Fa     33
# Ex     24
# Po     20
# Name: FireplaceQu, dtype: int64

# %% [markdown]
# Посмотрим на процентное соотношения классов FireplaceQu ко всему train

# %%
train["FireplaceQu"].value_counts()*100 / train.shape[0]
# Out:
# Gd    26.027397
# TA    21.438356
# Fa     2.260274
# Ex     1.643836
# Po     1.369863
# Name: FireplaceQu, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца FireplaceQu

# %% [markdown]
# Заполним пропущенные значения методом машинного обучения

# %%
train = fil_pass_ML(train,"FireplaceQu")
# Out:
# Learning rate set to 0.077195
# 0:	learn: 1.5850932	total: 19.6ms	remaining: 19.5s
# 100:	learn: 0.6892495	total: 16.5s	remaining: 2m 26s
# 200:	learn: 0.3369394	total: 34.6s	remaining: 2m 17s
# 300:	learn: 0.2444426	total: 52.9s	remaining: 2m 2s
# 400:	learn: 0.1973343	total: 1m 11s	remaining: 1m 47s
# 500:	learn: 0.1645638	total: 1m 30s	remaining: 1m 30s
# 600:	learn: 0.1421430	total: 1m 49s	remaining: 1m 12s
# 700:	learn: 0.1231448	total: 2m 8s	remaining: 54.7s
# 800:	learn: 0.1092760	total: 2m 26s	remaining: 36.5s
# 900:	learn: 0.0969888	total: 2m 45s	remaining: 18.2s
# 999:	learn: 0.0865334	total: 3m 3s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Ex       0.00      0.00      0.00         2
#           Fa       0.33      0.12      0.18         8
#           Gd       0.78      0.69      0.73        81
#           Po       0.00      0.00      0.00         1
# ...

# %%
train[train["FireplaceQu"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец GarageType

# %%
train["GarageType"].isna().mean()*100
# Out:
# 5.5479452054794525

# %%
train["GarageType"].value_counts(dropna=True)
# Out:
# Attchd     870
# Detchd     387
# BuiltIn     88
# Basment     19
# CarPort      9
# 2Types       6
# Name: GarageType, dtype: int64

# %% [markdown]
# Посмотрим на процентное соотношения классов GarageType ко всему train

# %%
train["GarageType"].value_counts()*100 / train.shape[0]
# Out:
# Attchd     59.589041
# Detchd     26.506849
# BuiltIn     6.027397
# Basment     1.301370
# CarPort     0.616438
# 2Types      0.410959
# Name: GarageType, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца GarageType

# %% [markdown]
# Заполним пропущенные значения методом машинного обучения

# %%
train = fil_pass_ML(train,"GarageType")
# Out:
# Learning rate set to 0.079523
# 0:	learn: 1.7592464	total: 69ms	remaining: 1m 8s
# 100:	learn: 0.4664261	total: 22.2s	remaining: 3m 17s
# 200:	learn: 0.2065667	total: 50s	remaining: 3m 18s
# 300:	learn: 0.1520940	total: 1m 18s	remaining: 3m 3s
# 400:	learn: 0.1309054	total: 1m 48s	remaining: 2m 41s
# 500:	learn: 0.1146813	total: 2m 18s	remaining: 2m 17s
# 600:	learn: 0.1037307	total: 2m 48s	remaining: 1m 51s
# 700:	learn: 0.0947970	total: 3m 18s	remaining: 1m 24s
# 800:	learn: 0.0882862	total: 3m 47s	remaining: 56.6s
# 900:	learn: 0.0821187	total: 4m 17s	remaining: 28.3s
# 999:	learn: 0.0764031	total: 4m 47s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#       2Types       0.00      0.00      0.00         4
#       Attchd       0.86      0.84      0.85       165
#      Basment       0.50      0.20      0.29         5
#      BuiltIn       0.61      0.81      0.69        21
# ...

# %%
train[train["GarageType"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец GarageFinish

# %%
train["GarageFinish"].isna().mean()*100
# Out:
# 5.5479452054794525

# %%
train["GarageFinish"].value_counts(dropna=False)
# Out:
# Unf    605
# RFn    422
# Fin    352
# NaN     81
# Name: GarageFinish, dtype: int64

# %% [markdown]
# Посмотрим на процентное соотношения классов GarageFinish ко всему train

# %%
train["GarageFinish"].value_counts()*100 / train.shape[0]
# Out:
# Unf    41.438356
# RFn    28.904110
# Fin    24.109589
# Name: GarageFinish, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца GarageFinish

# %% [markdown]
# Заполним пропущенные значения методом машинного обучения

# %%
train = fil_pass_ML(train,"GarageFinish")
# Out:
# Learning rate set to 0.079523
# 0:	learn: 1.0610112	total: 76.8ms	remaining: 1m 16s
# 100:	learn: 0.5755080	total: 9.11s	remaining: 1m 21s
# 200:	learn: 0.4381070	total: 17.7s	remaining: 1m 10s
# 300:	learn: 0.3541954	total: 26.7s	remaining: 1m 1s
# 400:	learn: 0.2887085	total: 35.2s	remaining: 52.6s
# 500:	learn: 0.2349606	total: 44s	remaining: 43.8s
# 600:	learn: 0.1998691	total: 52.8s	remaining: 35s
# 700:	learn: 0.1691475	total: 1m 1s	remaining: 26.3s
# 800:	learn: 0.1436547	total: 1m 10s	remaining: 17.5s
# 900:	learn: 0.1250587	total: 1m 18s	remaining: 8.65s
# 999:	learn: 0.1096265	total: 1m 27s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#          Fin       0.72      0.67      0.69        81
#          RFn       0.62      0.53      0.57        80
#          Unf       0.78      0.90      0.84       115
#
#     accuracy                           0.72       276
# ...

# %%
train[train["GarageFinish"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# ### Столбец GarageQual

# %%
train["GarageQual"].isna().mean()*100
# Out:
# 5.5479452054794525

# %%
train["GarageQual"].value_counts(dropna=False)
# Out:
# TA     1311
# NaN      81
# Fa       48
# Gd       14
# Ex        3
# Po        3
# Name: GarageQual, dtype: int64

# %% [markdown]
# Посмотрим на процентное соотношения классов GarageQual ко всему train

# %%
train["GarageQual"].value_counts()*100 / train.shape[0]
# Out:
# TA    89.794521
# Fa     3.287671
# Gd     0.958904
# Ex     0.205479
# Po     0.205479
# Name: GarageQual, dtype: float64

# %% [markdown]
# Классы несбалансированные. Закадируем переменные столбца GarageQual

# %% [markdown]
# Заполним пропущенные значения методом машинного обучения

# %%
train = fil_pass_ML(train,"GarageQual")
# Out:
# Learning rate set to 0.079523
# 0:	learn: 1.5416410	total: 244ms	remaining: 4m 3s
# 100:	learn: 0.3807105	total: 11.7s	remaining: 1m 44s
# 200:	learn: 0.0945383	total: 33.1s	remaining: 2m 11s
# 300:	learn: 0.0612694	total: 55.2s	remaining: 2m 8s
# 400:	learn: 0.0444035	total: 1m 17s	remaining: 1m 55s
# 500:	learn: 0.0347473	total: 1m 39s	remaining: 1m 39s
# 600:	learn: 0.0282472	total: 2m 1s	remaining: 1m 20s
# 700:	learn: 0.0235053	total: 2m 24s	remaining: 1m 1s
# 800:	learn: 0.0198311	total: 2m 45s	remaining: 41.2s
# 900:	learn: 0.0173437	total: 3m 7s	remaining: 20.6s
# 999:	learn: 0.0150324	total: 3m 29s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Ex       0.00      0.00      0.00         1
#           Fa       0.29      0.57      0.38         7
#           Gd       0.00      0.00      0.00         3
#           Po       0.00      0.00      0.00         1
# ...

# %%
train[train["GarageQual"].isna()]
# Out:
# Empty DataFrame
# Columns: [Id, MSSubClass, MSZoning, LotArea, Street, LotShape, LandContour, Utilities, LotConfig, LandSlope, Neighborhood, Condition1, Condition2, BldgType, HouseStyle, OverallQual, OverallCond, YearBuilt, YearRemodAdd, RoofStyle, RoofMatl, Exterior1st, Exterior2nd, MasVnrType, MasVnrArea, ExterQual, ExterCond, Foundation, BsmtQual, BsmtExposure, BsmtFinType1, BsmtFinSF1, BsmtFinSF2, BsmtUnfSF, TotalBsmtSF, Heating, HeatingQC, CentralAir, 1stFlrSF, 2ndFlrSF, LowQualFinSF, GrLivArea, BsmtFullBath, BsmtHalfBath, FullBath, HalfBath, BedroomAbvGr, KitchenAbvGr, KitchenQual, TotRmsAbvGrd, Functional, Fireplaces, FireplaceQu, GarageType, GarageYrBlt, GarageFinish, GarageCars, GarageArea, GarageQual, PavedDrive, WoodDeckSF, OpenPorchSF, EnclosedPorch, 3SsnPorch, ScreenPorch, PoolArea, MiscVal, MoSold, YrSold, SaleType, SaleCondition, SalePrice]
# Index: []

# %% [markdown]
# # Машинное обучение

# %% [markdown]
# ## Baseline без заполненных фичей

# %% [markdown]
# Сделаем Baseline, чтобы в дальнейшем от него отталкиваться в качестве нашей ML модели

# %%
main_train = train #клик

# %%
train_no_features = main_train.drop(["MasVnrArea","GarageYrBlt","MasVnrType","BsmtQual",
                                    "BsmtExposure","BsmtFinType1","FireplaceQu","GarageType",
                                    "GarageFinish","GarageQual"], axis = 1)

# %%
train, test =train_test_split(train_no_features,train_size = 0.8, random_state=42)
train, val = train_test_split(train,train_size = 0.75, random_state=42)

# %%
from catboost import CatBoostRegressor

# %%
categorical_features_indices = np.where(train_no_features.dtypes == np.object_)[0]

# %%
X = list(train_no_features)
X.remove("SalePrice")

# %%
y = ["SalePrice"]

# %%
from catboost import Pool

train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=categorical_features_indices
                 )

valid_data = Pool(data=val[X],
                  label=val[y],
                  cat_features=categorical_features_indices
                 )

# %%
params = {'verbose' : 300,
          'eval_metric' : 'RMSE', 
          'loss_function' : 'RMSE',
          'random_seed':42,
          "early_stopping_rounds":100}

# %%
model = CatBoostRegressor(**params)

# %%
model.fit(train_data,eval_set=valid_data)
# Out:
# Learning rate set to 0.049873
# 0:	learn: 74860.0446432	test: 75189.0893791	best: 75189.0893791 (0)	total: 38.2ms	remaining: 38.2s
# 300:	learn: 13657.8324962	test: 25050.7278895	best: 25042.4344564 (295)	total: 9.3s	remaining: 21.6s
# 600:	learn: 9052.5611672	test: 24422.5270490	best: 24376.2196809 (501)	total: 19.5s	remaining: 13s
# Stopped by overfitting detector  (100 iterations wait)
#
# bestTest = 24376.21968
# bestIteration = 501
#
# Shrink model to first 502 iterations.

# %%
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error

# %%
def error(y_true,y_pred):
  print(mean_absolute_error(y_true,y_pred))
  print(mean_absolute_percentage_error(y_true,y_pred))

# %%
test['price_pred_no_features'] = model.predict(test[X])

# %%
error(test['SalePrice'], test['price_pred_no_features'])
# Out:
# 16130.767741589456
# 0.09448465695293203

# %% [markdown]
# Получили абсолютную ошибку в 16130 - это значит, что настольков  среднем отклоняется наша *предсказанная* цена от настоящей
# Процентная абсолютная ошибка - 0.094, что означает, на какой процент отклоняется в среднем наша *предсказанная* переменная от настоящей

# %%
min_pct = mean_absolute_percentage_error(test['SalePrice'], test['price_pred_no_features'])

# %% [markdown]
# ## Baseline

# %%
train, test =train_test_split(main_train,train_size = 0.8, random_state=42)
train, val = train_test_split(train,train_size = 0.75, random_state=42)

# %%
categorical_features_indices = np.where(main_train.dtypes == np.object_)[0]

# %%
X = list(main_train)
X.remove("SalePrice")

# %%
y = ["SalePrice"]

# %%
from catboost import Pool

train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=categorical_features_indices
                 )

valid_data = Pool(data=val[X],
                  label=val[y],
                  cat_features=categorical_features_indices
                 )

# %%
params = {'verbose' : 300,
          'eval_metric' : 'RMSE', 
          'loss_function' : 'RMSE',
          'random_seed':42,
          "early_stopping_rounds":100}

# %%
model = CatBoostRegressor(**params)

# %%
model.fit(train_data,eval_set=valid_data)
# Out:
# Learning rate set to 0.049873
# 0:	learn: 74791.8189450	test: 74947.7419995	best: 74947.7419995 (0)	total: 32.3ms	remaining: 32.2s
# 300:	learn: 13259.1675492	test: 26076.4995310	best: 26076.4995310 (300)	total: 10.9s	remaining: 25.3s
# 600:	learn: 8974.9424645	test: 25432.3181088	best: 25432.3181088 (600)	total: 24.1s	remaining: 16s
# 900:	learn: 6557.3261455	test: 25156.2881515	best: 25154.8199101 (887)	total: 36.5s	remaining: 4.01s
# 999:	learn: 6064.9195335	test: 25089.4750612	best: 25089.4750612 (999)	total: 41.7s	remaining: 0us
#
# bestTest = 25089.47506
# bestIteration = 999

# %%
test['price_pred'] = model.predict(test[X])

# %%
error(test['SalePrice'], test['price_pred'])
# Out:
# 16609.50978638541
# 0.09719620317699895

# %% [markdown]
# Видим, что абослютная ошибка в Baseline без фичей меньше, чем с фичами, которые мы заполнили. Отсюда можно сделать вывод, что стоит отобрать оптимальное количество фичей для машинного обучения

# %% [markdown]
# ## Отбираем топ фичи

# %%
model.get_feature_importance(prettified=True)
# Out:
#        Feature Id  Importances
# 0     OverallQual    16.946955
# 1       GrLivArea    12.036403
# 2      GarageCars     7.549608
# 3        1stFlrSF     6.919548
# 4      BsmtFinSF1     4.599196
# 5       ExterQual     3.699100
# 6     TotalBsmtSF     3.590317
# 7        BsmtQual     3.406256
# 8         LotArea     3.228976
# 9     KitchenQual     2.883121
# 10     Fireplaces     2.396013
# 11   GarageFinish     2.352154
# 12       2ndFlrSF     2.199874
# 13     GarageArea     1.867517
# 14    OpenPorchSF     1.809735
# 15     GarageType     1.808225
# 16       HalfBath     1.701374
# 17   TotRmsAbvGrd     1.646217
# 18     WoodDeckSF     1.328257
# 19    OverallCond     1.323683
# 20       FullBath     1.305405
# 21   BsmtExposure     1.207212
# 22   Neighborhood     1.133094
# 23   YearRemodAdd     1.079657
# 24       MSZoning     0.876077
# 25      YearBuilt     0.820936
# 26  SaleCondition     0.815106
# 27     Foundation     0.629216
# 28     CentralAir     0.609639
# ...

# %% [markdown]
# Сохраним список всей фичей в all_top_feature, в котором фичи расположены по возрастанию согласно влиятельности фичи

# %%
all_top_feature = model.get_feature_importance(prettified=True)

# %% [markdown]
# Для каждого показателя кол-во фичей проведем кросс-валидацию, тем самым это позволит получить более уверенные результаты для каждого. Данную операцию **можно пропустить**. Время выполнения около 2-3 часов

# %%
from catboost import cv

# %%
from tqdm import tqdm

list_save_pct = []
for i in tqdm(range(5,71)):
    
    feature = list(all_top_feature.head(i)["Feature Id"]) 
    feature.append("SalePrice")
    search_train = main_train[list(feature)] #создаем набор данных с выбранным кол-во фичей

    train, test =train_test_split(search_train,train_size = 0.8, random_state=42)
    train, val = train_test_split(train,train_size = 0.75, random_state=42)

    categorical_features_indices = np.where(search_train.dtypes == np.object_)[0]
    X = list(search_train)
    X.remove("SalePrice")
    y = ["SalePrice"]  #отбираем переменные X, y, categorical_features

    train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=categorical_features_indices
                 )

    valid_data = Pool(data=val[X],
                  label=val[y],
                  cat_features=categorical_features_indices
                 )
    
    params = {
              'verbose' : False,
              'eval_metric' : 'RMSE', 
              'loss_function' : 'RMSE',
              'random_seed':42,
              "early_stopping_rounds":200}
    
    cv_date = cv(
    params = params,
    pool = train_data,
    fold_count = 5,
    shuffle=True,
    partition_random_seed=0,
    stratified=False,
    verbose=False
    )
    
    n_iters = cv_date[cv_date['test-RMSE-mean'] == cv_date['test-RMSE-mean'].min()].values[0][0]
    
    print("Лучшая итерация : ", n_iters)
    
    params = {'iterations':n_iters,
              'verbose' : False,
              'eval_metric' : 'RMSE', 
              'loss_function' : 'RMSE',
              'random_seed':42,
              "early_stopping_rounds":100}
    
    model = CatBoostRegressor(**params)
    model.fit(train_data,eval_set=valid_data)
    test[f'price_pred_{i}feat'] = model.predict(test[X])
    pct = mean_absolute_percentage_error(test['SalePrice'], test[f'price_pred_{i}feat'])
    list_save_pct.append([i,pct])
# Out:
#   0%|          | 0/66 [00:00<?, ?it/s]
# Training on fold [0/5]
#
# bestTest = 27096.31733
# bestIteration = 453
#
# Training on fold [1/5]
#
# bestTest = 28331.59033
# bestIteration = 187
#
# Training on fold [2/5]
#
# bestTest = 44216.75213
# bestIteration = 118
#
# Training on fold [3/5]
#
# bestTest = 28668.60848
# bestIteration = 538
#
# Training on fold [4/5]
#
# bestTest = 36278.87809
# bestIteration = 119
#
# Лучшая итерация :  172.0
#   2%|▏         | 1/66 [00:03<03:31,  3.25s/it]
# Training on fold [0/5]
#
# bestTest = 24198.14178
# bestIteration = 588
#
# Training on fold [1/5]
#
# bestTest = 26624.22571
# bestIteration = 529
#
# Training on fold [2/5]
#
# bestTest = 43285.14385
# bestIteration = 163
#
# Training on fold [3/5]
#
# bestTest = 31684.18848
# bestIteration = 579
#
# Training on fold [4/5]
#
# bestTest = 32684.61614
# bestIteration = 150
#
# Лучшая итерация :  579.0
#   3%|▎         | 2/66 [00:47<29:04, 27.26s/it]
# Training on fold [0/5]
#
# ...

# %%
pct = []
bins = []
for i in range(len(list_save_pct)):
    pct.append(list_save_pct[i][1])
    bins.append(list_save_pct[i][0])

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
fig, ax = plt.subplots()
ax.plot(bins, pct, color = 'r', linewidth = 1.5)

# %% [markdown]
# На графике показано значение абсолютной ошибки в зависимости от кол-во фичей, которые мы используем для машинного обучения. Самое минимальное значение абсолютной ошибки при кол-во фичей = 28

# %%
pct.index(np.min(pct))+5
# Out:
# 28

# %%
feature_top = all_top_feature.iloc[:28]["Feature Id"].to_list()

# %% [markdown]
# ## Подберем лучшие параметры через Hyperopt

# %%
# !pip install hyperopt

# %%
from hyperopt import hp

# %% [markdown]
# Подберем лучшие гиперпараметры для нашей модели. Для этого воспользуемся библиотекой Hyperopt. Данную операция **можно пропустить**. Время выполнения около 1 часа

# %%
feature_top.append("SalePrice")

# %%
search_train = main_train[list(feature_top)]

# %%
X_feature = list(search_train)
X_feature.remove("SalePrice")

# %%
categorical_features_indices = np.where(search_train.dtypes == np.object_)[0]
X = X_feature
y = ["SalePrice"]

# %%
x_train, x_val, y_train, y_val = train_test_split(search_train[X],search_train[y],train_size=0.8,random_state=42)

# %%
ctb_reg_params = {
    'learning_rate':     hp.loguniform('learning_rate', -5, 0),
    'colsample_bylevel': hp.choice('colsample_bylevel', np.arange(0.3, 0.8, 0.1)),
    'l2_leaf_reg':       hp.choice('l2_leaf_reg', np.arange(1, 8, 1)),
    'max_depth': hp.quniform('max_depth', 2, 10, 1),
    'n_estimators':  hp.quniform('n_estimators',  1500, 5000, 500),
    'random_seed' : 42,
    'eval_metric': 'RMSE', 
    'cat_features': categorical_features_indices
}
ctb_fit_params = {
    'early_stopping_rounds': 100,
    'verbose': False
}
ctb_para = dict()
ctb_para['reg_params'] = ctb_reg_params
ctb_para['fit_params'] = ctb_fit_params
ctb_para['loss_func' ] = lambda y, pred: mean_absolute_percentage_error(y, pred)

# %%
from hyperopt import fmin, tpe, STATUS_OK, STATUS_FAIL, Trials

# %%
class HPOpt(object):

    def __init__(self, x_train, x_val, y_train, y_val):
        self.x_train = x_train
        self.x_val  = x_val
        self.y_train = y_train
        self.y_val  = y_val

    def process(self, fn_name, space, trials, algo, max_evals):
        fn = getattr(self, fn_name)
        try:
            result = fmin(fn=fn, space=space, algo=algo, max_evals=max_evals, trials=trials)
        except Exception as e:
            return {'status': STATUS_FAIL,
                    'exception': str(e)}
        return result, trials
    
    def ctb_reg(self, para):
        reg = CatBoostRegressor(**para['reg_params'])
        return self.train_reg(reg, para)

    def train_reg(self, reg, para):
        reg.fit(self.x_train, self.y_train,
                eval_set=[(self.x_train, self.y_train), (self.x_val, self.y_val)],**para['fit_params'])
        pred = reg.predict(self.x_val)
        loss = para['loss_func'](self.y_val, pred)
        return {'loss': loss, 'status': STATUS_OK}

# %%
obj = HPOpt(x_train, x_val, y_train, y_val)

ctb_opt = obj.process(fn_name='ctb_reg', space=ctb_para, trials=Trials(), algo=tpe.suggest, max_evals=100)
# Out:
# 100%|██████████| 100/100 [37:02<00:00, 22.22s/trial, best loss: 0.08915434335582618]

# %% [markdown]
# Лучшие гиперпараметры

# %%
ctb_opt
# Out:
# ({'colsample_bylevel': 4,
#   'l2_leaf_reg': 5,
#   'learning_rate': 0.15414121168754188,
#   'max_depth': 5.0,
#   'n_estimators': 3500.0},
#  <hyperopt.base.Trials at 0x1fb0f96da60>)

# %% [markdown]
# ## Построим модель с найденными гиперпараметрами

# %%
train, test =train_test_split(search_train,train_size = 0.8, random_state=42)
train, val = train_test_split(train,train_size = 0.75, random_state=42)

# %%
train_data = Pool(data=train[X],
                  label=train[y],
                  cat_features=categorical_features_indices
                 )

valid_data = Pool(data=val[X],
                  label=val[y],
                  cat_features=categorical_features_indices
                 )

# %%
params = {'verbose' : 500,
          'eval_metric' : 'RMSE',
          'random_seed':42,
          'l2_leaf_reg': 5,
          'learning_rate': 0.15414121168754188,
          'max_depth': 5.0,
          'n_estimators': 3500.0,
          "loss_function" : "RMSE"}

# %%
model = CatBoostRegressor(**params)

# %%
model.fit(train_data,eval_set=valid_data)
# Out:
# 0:	learn: 70510.7728811	test: 71226.3836410	best: 71226.3836410 (0)	total: 15.4ms	remaining: 53.8s
# 500:	learn: 6673.7981983	test: 23705.3296825	best: 23657.9953392 (470)	total: 8.71s	remaining: 52.1s
# 1000:	learn: 3580.3723768	test: 23565.4321388	best: 23564.6005835 (998)	total: 18.1s	remaining: 45.3s
# 1500:	learn: 2194.9405946	test: 23576.0192449	best: 23545.4469216 (1408)	total: 27.8s	remaining: 37.1s
# 2000:	learn: 1518.2792503	test: 23559.2151575	best: 23545.4469216 (1408)	total: 37.3s	remaining: 27.9s
# 2500:	learn: 1116.1223858	test: 23556.4777637	best: 23544.3596957 (2068)	total: 45.4s	remaining: 18.1s
# 3000:	learn: 861.8409744	test: 23558.3296053	best: 23544.3596957 (2068)	total: 54.1s	remaining: 8.99s
# 3499:	learn: 708.9459177	test: 23556.1435560	best: 23544.3596957 (2068)	total: 1m 2s	remaining: 0us
#
# bestTest = 23544.3597
# bestIteration = 2068
#
# Shrink model to first 2069 iterations.

# %%
test['price_pred_hyperparameters'] = model.predict(test[X])

# %%
error(test['SalePrice'], test['price_pred_hyperparameters'])
# Out:
# 15718.136811990584
# 0.09254051378882602

# %% [markdown]
# ## Сделаем кроссвалидацию на всех данных

# %%
train_full = pd.concat([train, val])

# %%
train_full_data = Pool(data=train_full[X],
                  label=train_full[y],
                  cat_features=categorical_features_indices
                 )

# %%
params = {'verbose' : 500,
          'eval_metric' : 'RMSE',
          'random_seed':42,
          'l2_leaf_reg': 0,
          'learning_rate': 0.024826212966352925,
          'max_depth': 3.0,
          "loss_function" : "RMSE",
          'n_estimators': 4500.0}

# %%
from catboost import cv

# %%
cv_date = cv(
    params = params,
    pool = train_full_data,
    fold_count = 5,
    shuffle=True,
    partition_random_seed=0,
    verbose=False
)
# Out:
# Training on fold [0/5]
#
# bestTest = 23141.1505
# bestIteration = 1579
#
# Training on fold [1/5]
#
# bestTest = 27835.10904
# bestIteration = 4474
#
# Training on fold [2/5]
#
# bestTest = 20778.32176
# bestIteration = 1976
#
# Training on fold [3/5]
#
# bestTest = 30825.42679
# bestIteration = 4248
#
# Training on fold [4/5]
#
# bestTest = 25564.26469
# bestIteration = 3467

# %% [markdown]
# Получим лучшую итерацию

# %%
cv_date[cv_date['test-RMSE-mean'] == cv_date['test-RMSE-mean'].min()].values[0][0]
# Out:
# 2633.0

# %%
n_iters = cv_date[cv_date['test-RMSE-mean'] == cv_date['test-RMSE-mean'].min()].values[0][0]

# %% [markdown]
# # Анализ таблицы test

# %%
test_main = pd.read_csv(r"C:\Users\lavru\juoyter_notebook\House_Prices\Table\test.csv")

# %%
test_main
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0     1461          20       RH         80.0    11622   Pave   NaN      Reg
# 1     1462          20       RL         81.0    14267   Pave   NaN      IR1
# 2     1463          60       RL         74.0    13830   Pave   NaN      IR1
# 3     1464          60       RL         78.0     9978   Pave   NaN      IR1
# 4     1465         120       RL         43.0     5005   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1454  2915         160       RM         21.0     1936   Pave   NaN      Reg
# 1455  2916         160       RM         21.0     1894   Pave   NaN      Reg
# 1456  2917          20       RL        160.0    20000   Pave   NaN      Reg
# 1457  2918          85       RL         62.0    10441   Pave   NaN      Reg
# 1458  2919          60       RL         74.0     9627   Pave   NaN      Reg
#
# ...

# %%
feature_top.remove("SalePrice")
feature_top.append("Id")

# %%
test_main = test_main[list(feature_top)]

# %% [markdown]
# Посмотрим на пропущенные данные по test

# %%
test_main.isna().mean()
# Out:
# OverallQual      0.000000
# GrLivArea        0.000000
# GarageCars       0.000685
# 1stFlrSF         0.000000
# BsmtFinSF1       0.000685
# ExterQual        0.000000
# TotalBsmtSF      0.000685
# BsmtQual         0.030158
# LotArea          0.000000
# KitchenQual      0.000685
# Fireplaces       0.000000
# GarageFinish     0.053461
# 2ndFlrSF         0.000000
# GarageArea       0.000685
# OpenPorchSF      0.000000
# GarageType       0.052090
# HalfBath         0.000000
# TotRmsAbvGrd     0.000000
# WoodDeckSF       0.000000
# OverallCond      0.000000
# FullBath         0.000000
# BsmtExposure     0.030158
# Neighborhood     0.000000
# YearRemodAdd     0.000000
# MSZoning         0.002742
# YearBuilt        0.000000
# SaleCondition    0.000000
# Foundation       0.000000
# Id               0.000000
# dtype: float64

# %% [markdown]
# Для нас важны категориальные фичи, поэтому отберем те которые имеют тип данных object

# %%
categorical_features = np.where(test_main.dtypes == np.object_)[0]

# %%
table_nan = test_main.iloc[:,categorical_features].isna().mean().reset_index()

# %%
table_nan
# Out:
#            index         0
# 0      ExterQual  0.000000
# 1       BsmtQual  0.030158
# 2    KitchenQual  0.000685
# 3   GarageFinish  0.053461
# 4     GarageType  0.052090
# 5   BsmtExposure  0.030158
# 6   Neighborhood  0.000000
# 7       MSZoning  0.002742
# 8  SaleCondition  0.000000
# 9     Foundation  0.000000

# %%
fear_nan = table_nan[table_nan[0]>0]["index"].to_list()

# %%
fear_nan
# Out:
# ['BsmtQual',
#  'KitchenQual',
#  'GarageFinish',
#  'GarageType',
#  'BsmtExposure',
#  'MSZoning']

# %% [markdown]
# ## Обработка пропущенных значений

# %% [markdown]
# ### Столбец GarageFinish

# %% [markdown]
# Заполним пропуски машинным обучением

# %%
test_main = fil_pass_ML(test_main, "GarageFinish")
# Out:
# Learning rate set to 0.079527
# 0:	learn: 1.0676004	total: 26.8ms	remaining: 26.8s
# 100:	learn: 0.6124413	total: 2.7s	remaining: 24.1s
# 200:	learn: 0.4535522	total: 6.18s	remaining: 24.6s
# 300:	learn: 0.3530746	total: 9.08s	remaining: 21.1s
# 400:	learn: 0.2855381	total: 11.9s	remaining: 17.8s
# 500:	learn: 0.2330598	total: 14.7s	remaining: 14.7s
# 600:	learn: 0.1967005	total: 17.5s	remaining: 11.6s
# 700:	learn: 0.1654654	total: 20.5s	remaining: 8.75s
# 800:	learn: 0.1420299	total: 23.3s	remaining: 5.79s
# 900:	learn: 0.1232367	total: 25.9s	remaining: 2.84s
# 999:	learn: 0.1080782	total: 28.4s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#          Fin       0.60      0.61      0.60        69
#          RFn       0.58      0.51      0.54        81
#          Unf       0.77      0.83      0.80       127
#
#     accuracy                           0.68       277
# ...

# %% [markdown]
# ### Столбец KitchenQual

# %% [markdown]
# Заполним пропуски машинным обучением

# %%
test_main = fil_pass_ML(test_main, "KitchenQual")
# Out:
# Learning rate set to 0.079749
# 0:	learn: 1.3247438	total: 40.1ms	remaining: 40s
# 100:	learn: 0.4120358	total: 3.97s	remaining: 35.3s
# 200:	learn: 0.2533281	total: 7.65s	remaining: 30.4s
# 300:	learn: 0.1979959	total: 11.6s	remaining: 26.9s
# 400:	learn: 0.1627569	total: 16.4s	remaining: 24.6s
# 500:	learn: 0.1372192	total: 20.6s	remaining: 20.6s
# 600:	learn: 0.1164837	total: 24.1s	remaining: 16s
# 700:	learn: 0.1021429	total: 27.8s	remaining: 11.8s
# 800:	learn: 0.0896290	total: 31.6s	remaining: 7.86s
# 900:	learn: 0.0792720	total: 35.6s	remaining: 3.92s
# 999:	learn: 0.0702802	total: 40s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Ex       0.74      0.85      0.79        20
#           Fa       0.00      0.00      0.00         6
#           Gd       0.86      0.74      0.80       108
#           TA       0.83      0.89      0.86       158
#
# ...

# %%
test_main[test_main["KitchenQual"].isna()]
# Out:
# Empty DataFrame
# Columns: [OverallQual, GrLivArea, GarageCars, 1stFlrSF, BsmtFinSF1, ExterQual, TotalBsmtSF, BsmtQual, LotArea, KitchenQual, Fireplaces, GarageFinish, 2ndFlrSF, GarageArea, OpenPorchSF, GarageType, HalfBath, TotRmsAbvGrd, WoodDeckSF, OverallCond, FullBath, BsmtExposure, Neighborhood, YearRemodAdd, MSZoning, YearBuilt, SaleCondition, Foundation, Id]
# Index: []

# %% [markdown]
# ### Столбец BsmtQual

# %%
test_main = fil_pass_ML(test_main, "BsmtQual")
# Out:
# Learning rate set to 0.079629
# 0:	learn: 1.3118057	total: 44.1ms	remaining: 44.1s
# 100:	learn: 0.3973620	total: 4.32s	remaining: 38.5s
# 200:	learn: 0.2538469	total: 9.55s	remaining: 38s
# 300:	learn: 0.1929725	total: 14.2s	remaining: 33s
# 400:	learn: 0.1604421	total: 18.9s	remaining: 28.2s
# 500:	learn: 0.1359884	total: 23.9s	remaining: 23.8s
# 600:	learn: 0.1155155	total: 28.9s	remaining: 19.2s
# 700:	learn: 0.1001288	total: 33.7s	remaining: 14.4s
# 800:	learn: 0.0865784	total: 37.9s	remaining: 9.42s
# 900:	learn: 0.0762229	total: 42.6s	remaining: 4.68s
# 999:	learn: 0.0683002	total: 47.4s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Ex       0.81      0.72      0.76        29
#           Fa       0.17      0.20      0.18        10
#           Gd       0.87      0.84      0.86       114
#           TA       0.85      0.88      0.87       130
#
# ...

# %% [markdown]
# ### Столбец BsmtExposure

# %%
test_main = fil_pass_ML(test_main, "BsmtExposure")
# Out:
# Learning rate set to 0.079629
# 0:	learn: 1.3620336	total: 52.8ms	remaining: 52.8s
# 100:	learn: 0.8349012	total: 4.88s	remaining: 43.4s
# 200:	learn: 0.5274447	total: 9.84s	remaining: 39.1s
# 300:	learn: 0.3682398	total: 14.2s	remaining: 33s
# 400:	learn: 0.2776041	total: 18.5s	remaining: 27.7s
# 500:	learn: 0.2148061	total: 23.1s	remaining: 23s
# 600:	learn: 0.1769323	total: 27.7s	remaining: 18.4s
# 700:	learn: 0.1503910	total: 32.3s	remaining: 13.8s
# 800:	learn: 0.1284465	total: 37s	remaining: 9.18s
# 900:	learn: 0.1120487	total: 42.4s	remaining: 4.65s
# 999:	learn: 0.0990030	total: 47.3s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#           Av       0.44      0.47      0.46        38
#           Gd       0.60      0.52      0.56        29
#           Mn       0.00      0.00      0.00        20
#           No       0.83      0.86      0.84       196
#
# ...

# %% [markdown]
# ### Столбец MSZoning

# %%
test_main = fil_pass_ML(test_main, "MSZoning")
# Out:
# Learning rate set to 0.079742
# 0:	learn: 1.5153735	total: 74.4ms	remaining: 1m 14s
# 100:	learn: 0.2214070	total: 6.37s	remaining: 56.7s
# 200:	learn: 0.0922773	total: 15.6s	remaining: 1m 1s
# 300:	learn: 0.0690676	total: 23.8s	remaining: 55.3s
# 400:	learn: 0.0559717	total: 32.1s	remaining: 47.9s
# 500:	learn: 0.0486473	total: 40.4s	remaining: 40.2s
# 600:	learn: 0.0419201	total: 47.5s	remaining: 31.5s
# 700:	learn: 0.0373039	total: 54.4s	remaining: 23.2s
# 800:	learn: 0.0334240	total: 1m 3s	remaining: 15.8s
# 900:	learn: 0.0301842	total: 1m 11s	remaining: 7.83s
# 999:	learn: 0.0275235	total: 1m 19s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#      C (all)       0.00      0.00      0.00         5
#           FV       0.82      0.95      0.88        19
#           RH       0.00      0.00      0.00         1
#           RL       0.98      0.95      0.96       217
# ...

# %% [markdown]
# ### Столбец GarageType

# %%
test_main = fil_pass_ML(test_main, "GarageType")
# Out:
# Learning rate set to 0.079534
# 0:	learn: 1.7346371	total: 101ms	remaining: 1m 40s
# 100:	learn: 0.4863181	total: 10.3s	remaining: 1m 32s
# 200:	learn: 0.2107420	total: 21.1s	remaining: 1m 23s
# 300:	learn: 0.1617823	total: 32.8s	remaining: 1m 16s
# 400:	learn: 0.1372328	total: 44.2s	remaining: 1m 6s
# 500:	learn: 0.1200825	total: 53.8s	remaining: 53.6s
# 600:	learn: 0.1064016	total: 1m 3s	remaining: 42.4s
# 700:	learn: 0.0943108	total: 1m 14s	remaining: 31.6s
# 800:	learn: 0.0854778	total: 1m 23s	remaining: 20.8s
# 900:	learn: 0.0778561	total: 1m 33s	remaining: 10.3s
# 999:	learn: 0.0716931	total: 1m 45s	remaining: 0us
#
# ___Отчет по основным метрикам для каждого класса___
#
#               precision    recall  f1-score   support
#
#       2Types       0.00      0.00      0.00         2
#       Attchd       0.94      0.86      0.90       176
#      Basment       0.00      0.00      0.00         2
#      BuiltIn       0.57      0.93      0.70        14
# ...

# %% [markdown]
# # Сделаем предсказание

# %% [markdown]
# ## Обучим нашу модель

# %%
train_full_data = Pool(data=train_full[X],
                  label=train_full[y],
                  cat_features=categorical_features_indices
                 )

# %%
params = {'verbose' : 500,
          'eval_metric' : 'RMSE',
          'random_seed':42,
          'l2_leaf_reg': 5,
          'learning_rate': 0.15414121168754188,
          'max_depth': 5.0,
          'n_estimators': n_iters,
          "loss_function" : "RMSE"}

# %%
model.fit(train_full_data,eval_set=valid_data)
# Out:
# 0:	learn: 69855.0968570	test: 69859.2351717	best: 69859.2351717 (0)	total: 15.1ms	remaining: 53s
# 500:	learn: 7648.7207266	test: 9702.4879563	best: 9702.4879563 (500)	total: 8.73s	remaining: 52.3s
# 1000:	learn: 4559.4337177	test: 7248.2914114	best: 7247.0017523 (999)	total: 17.1s	remaining: 42.6s
# 1500:	learn: 2884.4034421	test: 6075.2547750	best: 6075.2547750 (1500)	total: 27s	remaining: 36s
# 2000:	learn: 2046.3128718	test: 5622.0180224	best: 5619.5586326 (1989)	total: 35.9s	remaining: 26.9s
# 2500:	learn: 1522.0211720	test: 5379.8613847	best: 5379.1225184 (2497)	total: 45.6s	remaining: 18.2s
# 3000:	learn: 1136.5826493	test: 5183.9456118	best: 5183.9456118 (3000)	total: 54.8s	remaining: 9.11s
# 3499:	learn: 883.0976147	test: 5080.8794488	best: 5080.8794488 (3499)	total: 1m 2s	remaining: 0us
#
# bestTest = 5080.879449
# bestIteration = 3499

# %%
test['price_pred_finish'] = model.predict(test[X])

# %%
error(test['SalePrice'], test['price_pred_finish'])
# Out:
# 15507.680203615895
# 0.09419994685276235

# %% [markdown]
# ## Сделаем предсказание

# %%
test_main["SalePrice"] = model.predict(test_main[X])

# %%
test_main[['Id','SalePrice']].to_csv('my_pred1.csv', index = False)

# %%
from IPython.display import Image
from IPython.core.display import HTML 
Image(url= "https://i.ibb.co/jhty0K2/image.png")
# Out:
# <img src="https://i.ibb.co/jhty0K2/image.png"/>
